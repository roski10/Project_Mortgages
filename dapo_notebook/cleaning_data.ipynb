# %%
import numpy as np
import pandas as pd
from scipy.stats.mstats import winsorize

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Washington State HDMA 2016

# %%
file = "raw_data/Washington_State_HDMA-2016.csv"
data_original = pd.read_csv(file, decimal=',')

# %%
data = data_original.copy()
data.shape
# Out:
# (466566, 47)

# %%
# --- Data manipulation ---


def clean_data(data: pd.DataFrame):
    # Define list of columns to filter for "Information not provided" values
    filter_cols = ['applicant_ethnicity_name', 'applicant_race_name_1', 'applicant_sex_name',
                   'co_applicant_ethnicity_name', 'co_applicant_race_name_1', 'co_applicant_sex_name']

    # Filter for rows where "action_taken_name" is not equal to certain values
    data = data.loc[~data['action_taken_name'].isin(['Application withdrawn by applicant', 'Loan purchased by the institution', 'File closed for incompleteness'])]

    # Filter for rows where values in specified columns are not equal to "Information not provided"
    for col in filter_cols:
        data = data.loc[~data[col].isin(['Information not provided by applicant in mail, Internet, or telephone application'])]

        # Create a dictionary of county to region mappings
    county_to_region = {
        'Whatcom County': 'Northern Cascades','Skagit County': 'Northern Cascades','Snohomish County': 'Northern Cascades',
        'King County': 'Western Region','Pierce County': 'Western Region','Kitsap County': 'Western Region',
        'Island County': 'Western Region','San Juan County': 'Western Region','Jefferson County': 'Western Region',
        'Clallam County': 'Western Region','Mason County': 'Olympic Peninsula','Clark County': 'Southwest Washington',
        'Cowlitz County': 'Southwest Washington','Wahkiakum County': 'Southwest Washington','Skamania County': 'Southwest Washington',
        'Adams County': 'Eastern Washington','Asotin County': 'Eastern Washington','Benton County': 'Eastern Washington',
        'Chelan County': 'Eastern Washington','Columbia County': 'Eastern Washington','Douglas County': 'Eastern Washington',
        'Ferry County': 'Eastern Washington','Franklin County': 'Eastern Washington','Garfield County': 'Eastern Washington',
        'Grant County': 'Eastern Washington','Kittitas County': 'Eastern Washington','Klickitat County': 'Eastern Washington',
        'Lincoln County': 'Eastern Washington','Okanogan County': 'Eastern Washington','Pend Oreille County': 'Eastern Washington',
        'Spokane County': 'Eastern Washington','Stevens County': 'Eastern Washington','Walla Walla County': 'Eastern Washington',
        'Whitman County': 'Eastern Washington','Yakima County': 'Eastern Washington','Thurston County':'Western Region',
        'Lewis County': 'Western Region','Grays Harbor County': 'Western Region','Pacific County': 'Southwest Washington',
        'Seattle, Bellevue, Everett': 'Western Region','Tacoma, Lakewood':'Northern Cascades','Portland, Vancouver, Hillsboro':'Northern Cascades',
        'Spokane, Spokane Valley':'Eastern Washington'
    }

    # Add a new column to your dataframe containing the region for each county
    data['region'] = data['county_name'].map(county_to_region)

    # Drop rows with missing values in "county_name" column
    data = data.dropna(subset=['county_name'])

    # Create new column "loan_status" based on "action_taken_name"
    data['loan_status'] = np.where(data['action_taken_name'] == 'Loan originated', 'approved', 'not approved')

    # Drop irrelevant columns
    drop_cols = ['applicant_race_name_5', 'applicant_race_name_4', 'applicant_race_name_3',
                 'applicant_race_name_2', 'co_applicant_race_name_5', 'co_applicant_race_name_4',
                 'co_applicant_race_name_3', 'co_applicant_race_name_2', 'denial_reason_name_3',
                 'denial_reason_name_2', 'denial_reason_name_1', 'rate_spread', 'edit_status_name',
                 'state_abbr', 'respondent_id', 'agency_abbr', 'as_of_year', 'application_date_indicator',
                 'state_name', 'sequence_number', 'census_tract_number', 'action_taken_name', 'purchaser_type_name',
                 'county_name','msamd_name']

    data = data.drop(columns=drop_cols)

    # Winsorize numeric columns
    data.select_dtypes(exclude=['object']).apply(lambda x: winsorize(x, limits=[0.05, 0.05]), axis=0, raw=True)

    # create a list of columns to be converted
    cols_to_convert = [
        'tract_to_msamd_income','population','minority_population','number_of_owner_occupied_units',
        'number_of_1_to_4_family_units','loan_amount_000s','hud_median_family_income','applicant_income_000s'
    ]

    # use the astype() method to convert the dtype of columns
    data[cols_to_convert] = data[cols_to_convert].astype('float')

    print("\n✅ data cleaned")

    return data

# %%
data = clean_data(data)
# Out:
# ✅ data cleaned

# %%
data
# Out:
#         tract_to_msamd_income  population  minority_population  \
# 1                   83.370003      4915.0            23.990000
# 2                   91.129997      5075.0            11.820000
# 4                  162.470001      5183.0            10.500000
# 5                  119.629997      4775.0            18.889999
# 6                  103.209999      4745.0            33.070000
# ...                       ...         ...                  ...
# 452825             109.730003      5035.0            18.830000
# 452834              59.049999      3608.0            17.959999
# 464253             101.290001      8722.0            39.070000
# 466564              88.690002      4725.0            45.880001
# 466565             128.690002      3657.0            21.410000
#
#         number_of_owner_occupied_units  number_of_1_to_4_family_units  \
# 1                               1268.0                         1777.0
# 2                               1136.0                         1838.0
# 4                               1705.0                         2104.0
# 5                                954.0                         1332.0
# 6                               1337.0                         1442.0
# ...                                ...                            ...
# 452825                          1249.0                         1567.0
# 452834                           579.0                         1150.0
# 464253                          2012.0                         2432.0
# 466564                          1188.0                         1686.0
# 466565                          1156.0                         1244.0
#
#         loan_amount_000s  hud_median_family_income  applicant_income_000s  \
# 1                  240.0                   57900.0                   42.0
# 2                  241.0                   73300.0                  117.0
# 4                  417.0                   78100.0                  114.0
# 5                  206.0                   72300.0                    NaN
# 6                  356.0                   90300.0                    NaN
# ...                  ...                       ...                    ...
# 452825             280.0                   73300.0                  115.0
# 452834             300.0                   72300.0                   85.0
# 464253             319.0                   61400.0                   74.0
# 466564             255.0                   72300.0                   77.0
# 466565             319.0                   90300.0                   78.0
#
#                                        property_type_name  \
# 1       One-to-four family dwelling (other than manufa...
# 2       One-to-four family dwelling (other than manufa...
# 4       One-to-four family dwelling (other than manufa...
# 5       One-to-four family dwelling (other than manufa...
# 6       One-to-four family dwelling (other than manufa...
# ...                                                   ...
# 452825  One-to-four family dwelling (other than manufa...
# 452834  One-to-four family dwelling (other than manufa...
# 464253  One-to-four family dwelling (other than manufa...
# 466564  One-to-four family dwelling (other than manufa...
# 466565  One-to-four family dwelling (other than manufa...
#
#                  preapproval_name  ... hoepa_status_name  \
# 1                  Not applicable  ...  Not a HOEPA loan
# 2                  Not applicable  ...  Not a HOEPA loan
# 4                  Not applicable  ...  Not a HOEPA loan
# 5                  Not applicable  ...  Not a HOEPA loan
# 6                  Not applicable  ...  Not a HOEPA loan
# ...                           ...  ...               ...
# 452825  Preapproval was requested  ...  Not a HOEPA loan
# 452834  Preapproval was requested  ...  Not a HOEPA loan
# 464253  Preapproval was requested  ...  Not a HOEPA loan
# 466564  Preapproval was requested  ...  Not a HOEPA loan
# 466565  Preapproval was requested  ...  Not a HOEPA loan
#
#        co_applicant_sex_name co_applicant_race_name_1  \
# 1            No co-applicant          No co-applicant
# 2                     Female                    White
# 4                       Male                    White
# 5            No co-applicant          No co-applicant
# 6            No co-applicant          No co-applicant
# ...                      ...                      ...
# 452825                Female                    White
# 452834       No co-applicant          No co-applicant
# 464253                Female                    White
# 466564                Female                    White
# 466565       No co-applicant          No co-applicant
#
#        co_applicant_ethnicity_name applicant_sex_name  \
# 1                  No co-applicant               Male
# 2           Not Hispanic or Latino               Male
# 4           Not Hispanic or Latino             Female
# 5                  No co-applicant               Male
# 6                  No co-applicant               Male
# ...                            ...                ...
# 452825      Not Hispanic or Latino               Male
# 452834             No co-applicant               Male
# 464253      Not Hispanic or Latino               Male
# 466564      Not Hispanic or Latino               Male
# 466565             No co-applicant               Male
#
#             applicant_race_name_1 applicant_ethnicity_name  \
# 1                           White       Hispanic or Latino
# 2                           White   Not Hispanic or Latino
# 4                           White   Not Hispanic or Latino
# 5                           White   Not Hispanic or Latino
# 6                           White   Not Hispanic or Latino
# ...                           ...                      ...
# 452825                      White   Not Hispanic or Latino
# 452834                      White   Not Hispanic or Latino
# 464253                      White   Not Hispanic or Latino
# 466564                      White   Not Hispanic or Latino
# 466565  Black or African American   Not Hispanic or Latino
#
#                                         agency_name                region  \
# 1       Department of Housing and Urban Development    Eastern Washington
# 2       Department of Housing and Urban Development  Southwest Washington
# 4             Federal Deposit Insurance Corporation        Western Region
# 5         Office of the Comptroller of the Currency        Western Region
# 6       Department of Housing and Urban Development     Northern Cascades
# ...                                             ...                   ...
# 452825         Consumer Financial Protection Bureau  Southwest Washington
# 452834  Department of Housing and Urban Development        Western Region
# 464253  Department of Housing and Urban Development     Northern Cascades
# 466564  Department of Housing and Urban Development        Western Region
# 466565  Department of Housing and Urban Development     Northern Cascades
#
#          loan_status
# 1           approved
# 2           approved
# 4           approved
# 5           approved
# 6           approved
# ...              ...
# 452825  not approved
# 452834  not approved
# 464253  not approved
# 466564  not approved
# 466565  not approved
#
# [283225 rows x 24 columns]

# %%
data.shape
# Out:
# (283225, 24)

# %%
data.columns.to_list()
# Out:
# ['tract_to_msamd_income',
#  'rate_spread',
#  'population',
#  'minority_population',
#  'number_of_owner_occupied_units',
#  'number_of_1_to_4_family_units',
#  'loan_amount_000s',
#  'hud_median_family_income',
#  'applicant_income_000s',
#  'state_name',
#  'state_abbr',
#  'sequence_number',
#  'respondent_id',
#  'purchaser_type_name',
#  'property_type_name',
#  'preapproval_name',
#  'owner_occupancy_name',
#  'msamd_name',
#  'loan_type_name',
#  'loan_purpose_name',
#  'lien_status_name',
#  'hoepa_status_name',
#  'edit_status_name',
#  'denial_reason_name_3',
#  'denial_reason_name_2',
#  'denial_reason_name_1',
#  'county_name',
#  'co_applicant_sex_name',
#  'co_applicant_race_name_5',
#  'co_applicant_race_name_4',
#  'co_applicant_race_name_3',
#  'co_applicant_race_name_2',
#  'co_applicant_race_name_1',
#  'co_applicant_ethnicity_name',
#  'census_tract_number',
#  'as_of_year',
#  'application_date_indicator',
#  'applicant_sex_name',
#  'applicant_race_name_5',
#  'applicant_race_name_4',
#  'applicant_race_name_3',
#  'applicant_race_name_2',
#  'applicant_race_name_1',
#  'applicant_ethnicity_name',
#  'agency_name',
#  'agency_abbr',
#  'action_taken_name']

# %% [markdown]
# ## Cleaning Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466566 entries, 0 to 466565
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   tract_to_msamd_income           465951 non-null  object
#  1   rate_spread                     8638 non-null    object
#  2   population                      465956 non-null  float64
#  3   minority_population             465956 non-null  object
#  4   number_of_owner_occupied_units  465944 non-null  float64
#  5   number_of_1_to_4_family_units   465955 non-null  float64
#  6   loan_amount_000s                466566 non-null  int64
#  7   hud_median_family_income        465960 non-null  float64
#  8   applicant_income_000s           404533 non-null  float64
#  9   state_name                      466566 non-null  object
#  10  state_abbr                      466566 non-null  object
#  11  sequence_number                 466566 non-null  int64
#  12  respondent_id                   466566 non-null  object
#  13  purchaser_type_name             466566 non-null  object
#  14  property_type_name              466566 non-null  object
#  15  preapproval_name                466566 non-null  object
#  16  owner_occupancy_name            466566 non-null  object
#  17  msamd_name                      428292 non-null  object
#  18  loan_type_name                  466566 non-null  object
#  19  loan_purpose_name               466566 non-null  object
#  20  lien_status_name                466566 non-null  object
#  21  hoepa_status_name               466566 non-null  object
#  22  edit_status_name                74505 non-null   object
#  23  denial_reason_name_3            1246 non-null    object
#  24  denial_reason_name_2            6746 non-null    object
#  25  denial_reason_name_1            34499 non-null   object
#  26  county_name                     466199 non-null  object
#  27  co_applicant_sex_name           466566 non-null  object
#  28  co_applicant_race_name_5        14 non-null      object
#  29  co_applicant_race_name_4        21 non-null      object
#  30  co_applicant_race_name_3        105 non-null     object
#  31  co_applicant_race_name_2        1862 non-null    object
#  32  co_applicant_race_name_1        466566 non-null  object
#  33  co_applicant_ethnicity_name     466566 non-null  object
#  34  census_tract_number             465960 non-null  object
#  35  as_of_year                      466566 non-null  int64
#  36  application_date_indicator      466566 non-null  int64
#  37  applicant_sex_name              466566 non-null  object
#  38  applicant_race_name_5           46 non-null      object
#  39  applicant_race_name_4           68 non-null      object
#  40  applicant_race_name_3           297 non-null     object
#  41  applicant_race_name_2           4478 non-null    object
#  42  applicant_race_name_1           466566 non-null  object
#  43  applicant_ethnicity_name        466566 non-null  object
#  44  agency_name                     466566 non-null  object
#  45  agency_abbr                     466566 non-null  object
#  46  action_taken_name               466566 non-null  object
# dtypes: float64(5), int64(4), object(38)
# memory usage: 167.3+ MB

# %% [markdown]
# ### Check for missing values: Use functions such as isna(), isnull(), or notnull() to detect missing values in your dataset.

# %%
null_df = pd.concat([data.isnull().sum().sort_values(ascending=False),
                     data.notnull().sum().sort_values(ascending=True)],
                    axis=1, keys=['is_null', 'not_null'])

null_df['percent_null'] = round((null_df['is_null'] / len(data)) * 100, 2)

null_df
# Out:
#                                 is_null  not_null  percent_null
# co_applicant_race_name_5         466552        14        100.00
# co_applicant_race_name_4         466545        21        100.00
# applicant_race_name_5            466520        46         99.99
# applicant_race_name_4            466498        68         99.99
# co_applicant_race_name_3         466461       105         99.98
# applicant_race_name_3            466269       297         99.94
# denial_reason_name_3             465320      1246         99.73
# co_applicant_race_name_2         464704      1862         99.60
# applicant_race_name_2            462088      4478         99.04
# denial_reason_name_2             459820      6746         98.55
# rate_spread                      457928      8638         98.15
# denial_reason_name_1             432067     34499         92.61
# edit_status_name                 392061     74505         84.03
# applicant_income_000s             62033    404533         13.30
# msamd_name                        38274    428292          8.20
# number_of_owner_occupied_units      622    465944          0.13
# tract_to_msamd_income               615    465951          0.13
# number_of_1_to_4_family_units       611    465955          0.13
# population                          610    465956          0.13
# minority_population                 610    465956          0.13
# hud_median_family_income            606    465960          0.13
# census_tract_number                 606    465960          0.13
# county_name                         367    466199          0.08
# owner_occupancy_name                  0    466566          0.00
# co_applicant_ethnicity_name           0    466566          0.00
# agency_abbr                           0    466566          0.00
# agency_name                           0    466566          0.00
# applicant_ethnicity_name              0    466566          0.00
# applicant_race_name_1                 0    466566          0.00
# loan_amount_000s                      0    466566          0.00
# applicant_sex_name                    0    466566          0.00
# application_date_indicator            0    466566          0.00
# as_of_year                            0    466566          0.00
# co_applicant_race_name_1              0    466566          0.00
# loan_type_name                        0    466566          0.00
# state_name                            0    466566          0.00
# state_abbr                            0    466566          0.00
# sequence_number                       0    466566          0.00
# co_applicant_sex_name                 0    466566          0.00
# respondent_id                         0    466566          0.00
# purchaser_type_name                   0    466566          0.00
# property_type_name                    0    466566          0.00
# preapproval_name                      0    466566          0.00
# hoepa_status_name                     0    466566          0.00
# lien_status_name                      0    466566          0.00
# loan_purpose_name                     0    466566          0.00
# action_taken_name                     0    466566          0.00

# %%
cols_drop = ['applicant_race_name_5', 'applicant_race_name_4','applicant_race_name_3','applicant_race_name_2',
            'co_applicant_race_name_5','co_applicant_race_name_4','co_applicant_race_name_3','co_applicant_race_name_2',
            'denial_reason_name_3','denial_reason_name_2','denial_reason_name_1','rate_spread','edit_status_name',
            'respondent_id', 'state_abbr', 'agency_abbr','as_of_year', 'state_name', 'sequence_number'
           ]

# %%
data = data[data.columns.difference(cols_drop)]

# %%
print(f'data shape: {data.shape}')

data.isnull().sum().sort_values(ascending=False)
# Out:
# data shape: (466566, 28)
# applicant_income_000s             62033
# msamd_name                        38274
# number_of_owner_occupied_units      622
# tract_to_msamd_income               615
# number_of_1_to_4_family_units       611
# population                          610
# minority_population                 610
# census_tract_number                 606
# hud_median_family_income            606
# county_name                         367
# loan_purpose_name                     0
# purchaser_type_name                   0
# property_type_name                    0
# preapproval_name                      0
# owner_occupancy_name                  0
# loan_type_name                        0
# action_taken_name                     0
# loan_amount_000s                      0
# agency_name                           0
# hoepa_status_name                     0
# co_applicant_sex_name                 0
# co_applicant_race_name_1              0
# co_applicant_ethnicity_name           0
# application_date_indicator            0
# applicant_sex_name                    0
# applicant_race_name_1                 0
# applicant_ethnicity_name              0
# lien_status_name                      0
# dtype: int64

# %% [markdown]
# ### Check for duplicates: Use the duplicated() function to detect duplicate rows in your dataset.

# %%
data[data.duplicated()]
# Out:
#                                         action_taken_name  \
# 57                                        Loan originated
# 147                                       Loan originated
# 694                                       Loan originated
# 1762                                      Loan originated
# 1817                                      Loan originated
# ...                                                   ...
# 466338                  Loan purchased by the institution
# 466463                  Loan purchased by the institution
# 466492                  Loan purchased by the institution
# 466493                  Loan purchased by the institution
# 466559  Preapproval request denied by financial instit...
#
#                                         agency_name applicant_ethnicity_name  \
# 57             Consumer Financial Protection Bureau           Not applicable
# 147            Consumer Financial Protection Bureau           Not applicable
# 694            Consumer Financial Protection Bureau           Not applicable
# 1762           Consumer Financial Protection Bureau           Not applicable
# 1817           Consumer Financial Protection Bureau           Not applicable
# ...                                             ...                      ...
# 466338         Consumer Financial Protection Bureau           Not applicable
# 466463         Consumer Financial Protection Bureau           Not applicable
# 466492         Consumer Financial Protection Bureau           Not applicable
# 466493         Consumer Financial Protection Bureau           Not applicable
# 466559  Department of Housing and Urban Development   Not Hispanic or Latino
#
#         applicant_income_000s applicant_race_name_1 applicant_sex_name  \
# 57                        NaN        Not applicable     Not applicable
# 147                       NaN        Not applicable     Not applicable
# 694                       NaN        Not applicable     Not applicable
# 1762                      NaN        Not applicable     Not applicable
# 1817                      NaN        Not applicable     Not applicable
# ...                       ...                   ...                ...
# 466338                  244.0        Not applicable     Not applicable
# 466463                    NaN        Not applicable     Not applicable
# 466492                    NaN        Not applicable     Not applicable
# 466493                    NaN        Not applicable     Not applicable
# 466559                   42.0                 White               Male
#
#         application_date_indicator census_tract_number  \
# 57                               0              404.12
# 147                              0              404.12
# 694                              0              108.03
# 1762                             0               411.1
# 1817                             0               411.1
# ...                            ...                 ...
# 466338                           2                8.03
# 466463                           2                9.02
# 466492                           2                   1
# 466493                           2              103.03
# 466559                           0                 NaN
#
#        co_applicant_ethnicity_name co_applicant_race_name_1  ...  \
# 57                 No co-applicant          No co-applicant  ...
# 147                No co-applicant          No co-applicant  ...
# 694                No co-applicant          No co-applicant  ...
# 1762               No co-applicant          No co-applicant  ...
# 1817               No co-applicant          No co-applicant  ...
# ...                            ...                      ...  ...
# 466338              Not applicable           Not applicable  ...
# 466463              Not applicable           Not applicable  ...
# 466492              Not applicable           Not applicable  ...
# 466493              Not applicable           Not applicable  ...
# 466559             No co-applicant          No co-applicant  ...
#
#        minority_population                               msamd_name  \
# 57             16.56999969  Portland, Vancouver, Hillsboro - OR, WA
# 147            16.56999969  Portland, Vancouver, Hillsboro - OR, WA
# 694            14.73999977                 Kennewick, Richland - WA
# 1762           20.22999954  Portland, Vancouver, Hillsboro - OR, WA
# 1817           20.22999954  Portland, Vancouver, Hillsboro - OR, WA
# ...                    ...                                      ...
# 466338         17.67000008                          Bellingham - WA
# 466463         13.18000031                          Bellingham - WA
# 466492         20.92000008                          Bellingham - WA
# 466493         16.19000053                          Bellingham - WA
# 466559                 NaN                                      NaN
#
#        number_of_1_to_4_family_units  number_of_owner_occupied_units  \
# 57                            1506.0                          1207.0
# 147                           1506.0                          1207.0
# 694                           2137.0                          2037.0
# 1762                          1816.0                          1428.0
# 1817                          1816.0                          1428.0
# ...                              ...                             ...
# 466338                        2315.0                          1709.0
# 466463                        2216.0                          1752.0
# 466492                        2537.0                          2033.0
# 466493                        1440.0                          1167.0
# 466559                           NaN                             NaN
#
#                               owner_occupancy_name  population  \
# 57      Not owner-occupied as a principal dwelling      4333.0
# 147     Not owner-occupied as a principal dwelling      4333.0
# 694     Not owner-occupied as a principal dwelling      6690.0
# 1762    Not owner-occupied as a principal dwelling      5849.0
# 1817    Not owner-occupied as a principal dwelling      5849.0
# ...                                            ...         ...
# 466338  Not owner-occupied as a principal dwelling      6275.0
# 466463      Owner-occupied as a principal dwelling      5833.0
# 466492      Owner-occupied as a principal dwelling      8998.0
# 466493      Owner-occupied as a principal dwelling      5103.0
# 466559      Owner-occupied as a principal dwelling         NaN
#
#                  preapproval_name  \
# 57                 Not applicable
# 147                Not applicable
# 694                Not applicable
# 1762               Not applicable
# 1817               Not applicable
# ...                           ...
# 466338             Not applicable
# 466463             Not applicable
# 466492             Not applicable
# 466493             Not applicable
# 466559  Preapproval was requested
#
#                                        property_type_name  \
# 57      One-to-four family dwelling (other than manufa...
# 147     One-to-four family dwelling (other than manufa...
# 694     One-to-four family dwelling (other than manufa...
# 1762    One-to-four family dwelling (other than manufa...
# 1817    One-to-four family dwelling (other than manufa...
# ...                                                   ...
# 466338  One-to-four family dwelling (other than manufa...
# 466463  One-to-four family dwelling (other than manufa...
# 466492  One-to-four family dwelling (other than manufa...
# 466493  One-to-four family dwelling (other than manufa...
# 466559  One-to-four family dwelling (other than manufa...
#
#                                       purchaser_type_name  \
# 57      Loan was not originated or was not sold in cal...
# 147     Loan was not originated or was not sold in cal...
# 694     Loan was not originated or was not sold in cal...
# 1762    Loan was not originated or was not sold in cal...
# 1817    Loan was not originated or was not sold in cal...
# ...                                                   ...
# 466338                                Freddie Mac (FHLMC)
# 466463                                Freddie Mac (FHLMC)
# 466492                                Freddie Mac (FHLMC)
# 466493                                Freddie Mac (FHLMC)
# 466559  Loan was not originated or was not sold in cal...
#
#        tract_to_msamd_income
# 57               112.5599976
# 147              112.5599976
# 694              171.8899994
# 1762             87.29000092
# 1817             87.29000092
# ...                      ...
# 466338           122.0999985
# 466463                129.25
# 466492           100.2900009
# 466493           97.12000275
# 466559                   NaN
#
# [1652 rows x 28 columns]

# %%
print(f'Duplicates with respondant ID: {data_original.duplicated().sum()}')
print(f'Duplicates without respondant ID: {data.duplicated().sum()}')
# Out:
# Duplicates with respondant ID: 0
# Duplicates without respondant ID: 1652

# %% [markdown]
# - Same applicant applied twice as they had a different respondent ID

# %% [markdown]
# ### Check for inconsistent values: Look for inconsistent values across different columns in your dataset.

# %%
# for i in data:
#     print("\n",i,":\n",data[i].unique())

# %% [markdown]
# ### Handle inconsistent values: Deleting the rows with inconsistent values.

# %%
data = data[~data['action_taken_name'].isin(['Application withdrawn by applicant', 'Loan purchased by the institution', 'File closed for incompleteness'])]
data = data[~data['applicant_ethnicity_name'].isin(['Information not provided by applicant in mail, Internet, or telephone application'])]
data = data[~data['applicant_race_name_1'].isin(['Information not provided by applicant in mail, Internet, or telephone application'])]
data = data[~data['applicant_sex_name'].isin(['Information not provided by applicant in mail, Internet, or telephone application'])]
data = data[~data['co_applicant_ethnicity_name'].isin(['Information not provided by applicant in mail, Internet, or telephone application'])]
data = data[~data['co_applicant_race_name_1'].isin(['Information not provided by applicant in mail, Internet, or telephone application'])]
data = data[~data['co_applicant_sex_name'].isin(['Information not provided by applicant in mail, Internet, or telephone application'])]
data =  data.dropna(subset=['county_name'])

# %%
print(f'Data Shape: {data.shape}')
# Out:
# Data Shape: (283225, 28)

# %% [markdown]
# ### Check for outliers: Look for data points that are significantly different from the other data points in your dataset.

# %%
data_original.describe()
# Out:
#           population  number_of_owner_occupied_units  \
# count  465956.000000                    465944.00000
# mean     5288.219117                      1389.05978
# std      1665.350069                       506.75606
# min         5.000000                        10.00000
# 25%      4124.000000                      1032.00000
# 50%      5173.000000                      1359.00000
# 75%      6342.000000                      1705.00000
# max     13025.000000                      2997.00000
#
#        number_of_1_to_4_family_units  loan_amount_000s  \
# count                  465955.000000     466566.000000
# mean                     1822.137288        298.260936
# std                       682.031693        760.741532
# min                        10.000000          1.000000
# 25%                      1395.000000        172.000000
# 50%                      1734.000000        248.000000
# 75%                      2171.000000        350.000000
# max                      5893.000000      99999.000000
#
#        hud_median_family_income  applicant_income_000s  sequence_number  \
# count             465960.000000          404533.000000     4.665660e+05
# mean               76797.148468             112.984713     1.126340e+05
# std                12959.051933             125.115972     2.020830e+05
# min                48700.000000               1.000000     1.000000e+00
# 25%                65800.000000              60.000000     5.121000e+03
# 50%                73300.000000              89.000000     2.647200e+04
# 75%                90300.000000             133.000000     1.095258e+05
# max                90300.000000            9999.000000     1.241780e+06
#
#        as_of_year  application_date_indicator
# count    466566.0               466566.000000
# mean       2016.0                    0.207285
# std           0.0                    0.609593
# min        2016.0                    0.000000
# 25%        2016.0                    0.000000
# 50%        2016.0                    0.000000
# 75%        2016.0                    0.000000
# max        2016.0                    2.000000

# %%
df_selected = data.drop(data.select_dtypes('object').columns.tolist(),axis=1)

for i in df_selected:
    data[i] = winsorize(data[i], limits=[0.05, 0.05])

data.describe()
# Out:
#        applicant_income_000s  application_date_indicator  \
# count          260191.000000                    283225.0
# mean              111.604275                         0.0
# std               117.842795                         0.0
# min                34.000000                         0.0
# 25%                59.000000                         0.0
# 50%                88.000000                         0.0
# 75%               131.000000                         0.0
# max              6977.000000                         0.0
#
#        hud_median_family_income  loan_amount_000s  \
# count             283225.000000     283225.000000
# mean               76810.852502        269.338254
# std                12719.400941        134.807431
# min                55600.000000         68.000000
# 25%                65800.000000        171.000000
# 50%                73300.000000        246.000000
# 75%                90300.000000        348.000000
# max                90300.000000        581.000000
#
#        number_of_1_to_4_family_units  number_of_owner_occupied_units  \
# count                  283225.000000                   283225.000000
# mean                     1806.623713                     1387.604226
# std                       564.047536                      468.496248
# min                       910.000000                      597.000000
# 25%                      1397.000000                     1032.000000
# 50%                      1735.000000                     1361.000000
# 75%                      2175.000000                     1709.000000
# max                      2976.000000                     2307.000000
#
#           population
# count  283225.000000
# mean     5257.295631
# std      1474.125310
# min      2788.000000
# 25%      4125.000000
# 50%      5175.000000
# 75%      6342.000000
# max      7983.000000

# %% [markdown]
# - we're replacing the lowest 5% of values with the value at the 5th percentile, and the highest 5% of values with the value at the 95th percentile, using the 'winsorize' function from 'scipy.stats.mstats'.

# %%
data.isnull().sum()
# Out:
# action_taken_name                     0
# agency_name                           0
# applicant_ethnicity_name              0
# applicant_income_000s             23034
# applicant_race_name_1                 0
# applicant_sex_name                    0
# application_date_indicator            0
# census_tract_number                  68
# co_applicant_ethnicity_name           0
# co_applicant_race_name_1              0
# co_applicant_sex_name                 0
# county_name                           0
# hoepa_status_name                     0
# hud_median_family_income              0
# lien_status_name                      0
# loan_amount_000s                      0
# loan_purpose_name                     0
# loan_type_name                        0
# minority_population                  70
# msamd_name                        23339
# number_of_1_to_4_family_units         0
# number_of_owner_occupied_units        0
# owner_occupancy_name                  0
# population                            0
# preapproval_name                      0
# property_type_name                    0
# purchaser_type_name                   0
# tract_to_msamd_income                73
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 data = clean_data(data)
#
# Cell In [19], line 53, in clean_data(data)
#      44 # Drop irrelevant columns
#      45 drop_cols = ['applicant_race_name_5', 'applicant_race_name_4', 'applicant_race_name_3',
#      46              'applicant_race_name_2', 'co_applicant_race_name_5', 'co_applicant_race_name_4',
#      47              'co_applicant_race_name_3', 'co_applicant_race_name_2', 'denial_reason_name_3',
#    (...)
#      50              'state_name', 'sequence_number', 'census_tract_number', 'action_taken_name', 'purchaser_type_name',
#      51              'county_name','msamd_name']
# ---> 53 data = data.drop(columns=drop_cols)
#      55 # Winsorize numeric columns
#      56 data.select_dtypes(exclude=['object']).apply(lambda x: winsorize(x, limits=[0.05, 0.05]), axis=0, raw=True)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
#    5245     self,
#    (...)
#    5252     errors: IgnoreRaise = "raise",
#    5253 ) -> DataFrame | None:
#    5254     """
#    5255     Drop specified labels from rows or columns.
#    5256
#    (...)
#    5389             weight  1.0     0.8
#    5390     """
# -> 5391     return super().drop(
#    5392         labels=labels,
#    5393         axis=axis,
#    5394         index=index,
#    5395         columns=columns,
#    5396         level=level,
#    5397         inplace=inplace,
#    5398         errors=errors,
#    5399     )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:4510, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4508 for axis, labels in axes.items():
#    4509     if labels is not None:
# -> 4510         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4512 if inplace:
#    4513     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:4551, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4549         new_axis = axis.drop(labels, level=level, errors=errors)
#    4550     else:
# -> 4551         new_axis = axis.drop(labels, errors=errors)
#    4552     indexer = axis.get_indexer(new_axis)
#    4554 # Case for non-unique axis
#    4555 else:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:6972, in Index.drop(self, labels, errors)
#    6970 if mask.any():
#    6971     if errors != "ignore":
# -> 6972         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6973     indexer = indexer[~mask]
#    6974 return self.delete(indexer)
#
# KeyError: "['applicant_race_name_5', 'applicant_race_name_4', 'applicant_race_name_3', 'applicant_race_name_2', 'co_applicant_race_name_5', 'co_applicant_race_name_4', 'co_applicant_race_name_3', 'co_applicant_race_name_2', 'denial_reason_name_3', 'denial_reason_name_2', 'denial_reason_name_1', 'rate_spread', 'edit_status_name', 'state_abbr', 'respondent_id', 'agency_abbr', 'as_of_year', 'state_name', 'sequence_number'] not found in axis"
